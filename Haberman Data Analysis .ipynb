# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

Haberman=pd.read_csv("haberman.csv")

# %%
print(Haberman.shape)
# Out:
# (305, 4)

# %%
print (Haberman.columns)
Haberman.head(7)
# Out:
# Index(['Age', 'Op_year', 'axil_nodes', 'Survived_morethan_5years'], dtype='object')
#    Age  Op_year  axil_nodes  Survived_morethan_5years
# 0   30       62           3                         1
# 1   30       65           0                         1
# 2   31       59           2                         1
# 3   31       65           4                         1
# 4   33       58          10                         1
# 5   33       60           0                         1
# 6   34       59           0                         2

# %%
Haberman["Survived_morethan_5years"] = Haberman["Survived_morethan_5years"].map({1:"yes", 2:"no"})

# %%
Haberman.head()
# Out:
#    Age  Op_year  axil_nodes Survived_morethan_5years
# 0   30       62           3                      yes
# 1   30       65           0                      yes
# 2   31       59           2                      yes
# 3   31       65           4                      yes
# 4   33       58          10                      yes

# %%
Haberman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
# Age                         305 non-null int64
# Op_year                     305 non-null int64
# axil_nodes                  305 non-null int64
# Survived_morethan_5years    305 non-null object
# dtypes: int64(3), object(1)
# memory usage: 9.6+ KB

# %%
Haberman["Survived_morethan_5years"].value_counts()
# Out:
# yes    224
# no      81
# Name: Survived_morethan_5years, dtype: int64

# %%
Haberman.plot(kind='scatter', x='Age', y='Op_year') ;
plt.show()

# %%
Haberman.plot(kind='scatter', x='Age', y='axil_nodes') ;
plt.show()

# %%
Haberman.plot(kind='scatter', x='Op_year', y='axil_nodes') ;
plt.show()

# %%
#pair_plot
plt.close();
sns.set_style("whitegrid");
sns.pairplot(Haberman, hue="Survived_morethan_5years", size=4);
plt.show()

# %%
sns.FacetGrid(Haberman, hue="Survived_morethan_5years", size=5) \
   .map(sns.distplot, "Age") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Anand\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Anand\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(Haberman, hue="Survived_morethan_5years", size=5) \
   .map(sns.distplot, "Op_year") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Anand\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Anand\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(Haberman, hue="Survived_morethan_5years", size=5) \
   .map(sns.distplot, "axil_nodes") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Anand\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Anand\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.boxplot(x='Survived_morethan_5years',y='axil_nodes', data=Haberman)
plt.show()

# %%
sns.boxplot(x='Survived_morethan_5years',y='Op_year', data=Haberman)
plt.show()

# %%
sns.boxplot(x='Survived_morethan_5years',y='Age', data=Haberman)
plt.show()

# %%
sns.violinplot(x="Survived_morethan_5years", y="Age", data=Haberman, size=8)
plt.show()
